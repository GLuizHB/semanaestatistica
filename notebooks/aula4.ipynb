# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = 10
print(type(x))
y = 3j
print(type(y))
# Out:
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# ## Exercício - revisão
# """
#     Qual é sua a altura?
#     Qual é seu peso?
#     Qual o seu IMC?
#
#     função (mundo é baseado em funções)
#     IMC = peso/altura²
#
# """

# %%
altura = float(input("Qual é sua altura: ").replace(",","."))
peso = float(input("Qual é seu peso: "))

imc = peso / (altura ** 2)
print(f"seu IMC é: {imc:.2f}")

if imc < 18.5:
    print("Abaixo do peso")
elif 18.5 <= imc < 24.9:
    print("Peso normal")
elif 25 <= imc < 29.9:
    print("Sobrepeso")
elif 30 <= imc < 34.9:
    print("Obesidade Grau 1")
elif 35 <= imc < 39.9:
    print("Obesidade Grau 2")
else:
    print("Obesidade Grau 3 (Obesidade Mórbida)")
# Out:
# seu IMC é: 0.01
# Abaixo do peso

# %% [markdown]
# # Após a revisão iniciaremos a visualização de dados (Data Visualizacion)

# %% [markdown]
# - Visualizar a imigração de Brasileiros de 1980 até 2013
# - Verificar as tendencias

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.0-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.1.0-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/imigrantes_canada.csv')
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %% [markdown]
# # Coluna "País"

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df["País"]
# Out:
# 0          Afeganistão
# 1              Albânia
# 2              Argélia
# 3      Samoa Americana
# 4              Andorra
#             ...
# 190             Vietnã
# 191    Saara Ocidental
# 192              Iémen
# 193             Zâmbia
# 194           Zimbábue
# Name: País, Length: 195, dtype: object

# %%
df.set_index('País',inplace=True)

# %%
anos = list(map(str,range(1980,2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil',anos]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
print(type(brasil))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## pandas = series e dataframes

# %%
brasil_dict = {'ano':brasil.index.tolist(),'imigrantes':brasil.values.tolist()}
brasil_dict
# Out:
# {'ano': ['1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013'],
#  'imigrantes': [np.int64(211),
#   np.int64(220),
#   np.int64(192),
#   np.int64(139),
#   np.int64(145),
#   np.int64(130),
#   np.int64(205),
#   np.int64(244),
#   np.int64(394),
#   np.int64(650),
#   np.int64(650),
#   np.int64(877),
#   np.int64(1066),
#   np.int64(866),
#   np.int64(566),
#   np.int64(572),
#   np.int64(586),
#   np.int64(591),
#   np.int64(531),
#   np.int64(626),
#   np.int64(845),
#   np.int64(847),
#   np.int64(745),
#   np.int64(839),
#   np.int64(917),
#   np.int64(969),
#   np.int64(1181),
#   np.int64(1746),
#   np.int64(2138),
# ...

# %%
dados_brasil = pd.DataFrame(brasil_dict)
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %% [markdown]
# # Gráfico de linha

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.ticker import MultipleLocator

# %%
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='green')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500,1000,1500,2000,2500,3000])
plt.title('Gráfico de imigração de Brasileiros para o Canadá')
plt.grid()
plt.show()

# %% [markdown]
# # Transformando um gráficoem figura

# %%
plt.figure(figsize=(8,5))
# 1 polegada = 2.54 cm
# largura 8 = 20.32 cm
# altura 4 = 10.16 cm
# PDI (dots per inch, ou pontos por polegada)
# Padrão no matplolib - DPI = 100
# Largura : 8 polegadas x 100 DPI = 800 pixels
# Altura : 4 polegadas x 100 DPI = 400 pixels
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='green',markersize=3, )
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500,1000,1500,2000,2500,3000])
plt.title('Gráfico de imigração de Brasileiros para o Canadá')
plt.annotate('Pico de imigração', xy=(29, 2600), xytext=(15, 1500),
             arrowprops=dict(facecolor='red', shrink=0.20))
plt.grid()
plt.show()

# %% [markdown]
# # Inicio da aula 2

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='green',markersize=3, marker='o',markerfacecolor='white' )
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500,1000,1500,2000,2500,3000])
plt.title('Gráfico de imigração de Brasileiros para o Canadá', color='green')
plt.xlabel('Ano',fontsize=14)
plt.ylabel('imigrantes',fontsize=16)
plt.annotate('(Pico de imigração)', xy=(28, 2760), xytext=(40, 1700),
             arrowprops=dict(facecolor='red', shrink=0.20))
plt.fill_between(dados_brasil['ano'], dados_brasil['imigrantes'], color='darkgrey', alpha=0.7)

plt.grid()
plt.show()

# %%
# Criando um 
fig,axs = plt.subplots(1,2,figsize=(15,6))

# Subplot 1: Gráfico de linha
axs[0].plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='red', marker='o', markersize=3,markerfacecolor='white')
axs[0].xaxis.set_major_locator(MultipleLocator(5))
axs[0].set_title("Imigração do Brasil para o Canadá\nde 1980 a 2013")
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Número de imigrantes')
axs[0].fill_between(dados_brasil['ano'], dados_brasil['imigrantes'], color='darkgrey', alpha=0.7)
axs[0].grid()

# Subplot 2: Gráfico Boxplot
axs[1].violinplot(dados_brasil['imigrantes'])
axs[1].set_title("Violinplot da imigração do Brasil para o Canadá de \nde 1980 a 2013")
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()


plt.show()

# %% [markdown]
# # Comparativos de imigrações do Brasil com alguns paises da LATAM

# %%
# Criando um subplot
fig, axs = plt.subplots(2,2,figsize=(15,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
# wspace - espaço horizontal
# hspace -espaço vertical

# subplots 
# Brasil
axs[0,0].plot(df.loc['Brasil',anos])
axs[0,0].set_title('Brasil')
axs[0,0].xaxis.set_major_locator(MultipleLocator(5))

# Colômbia
axs[0,1].plot(df.loc['Colômbia',anos])
axs[0,1].set_title('Colômbia')
axs[0,1].xaxis.set_major_locator(MultipleLocator(5))

# Argentina
axs[1,0].plot(df.loc['Argentina',anos])
axs[1,0].set_title('Argentina')
axs[1,0].xaxis.set_major_locator(MultipleLocator(5))

# Peru
axs[1,1].plot(df.loc['Peru',anos])
axs[1,1].set_title('Peru')
axs[1,1].xaxis.set_major_locator(MultipleLocator(5))

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
    ax.set_xlabel('Ano', fontsize=10)
    ax.set_ylabel('Número de Imigrantes', fontsize=10)


# Usando ravel() - achatar a matriz evitandoo uso completo 
# Usando set_ylim() - definindo o limite dos valores.
ymin = 0
ymax = 7000

for ax in axs.ravel():
    ax.set_ylim(ymin,ymax)

    
plt.show()

# %%
# Criando um subplot
fig, ax = plt.subplots(figsize=(15,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Imigração na América Latina", fontsize=14)
# wspace - espaço horizontal
# hspace -espaço vertical

# subplots 
# Brasil
ax.plot(df.loc['Brasil',anos],color='green')
ax.xaxis.set_major_locator(MultipleLocator(5))

# Colômbia
ax.plot(df.loc['Colômbia',anos], color='darkorange')
ax.xaxis.set_major_locator(MultipleLocator(5))

# Argentina
ax.plot(df.loc['Argentina',anos],color='dodgerblue')
ax.xaxis.set_major_locator(MultipleLocator(5))

# Peru
ax.plot(df.loc['Peru',anos],color='red')
ax.xaxis.set_major_locator(MultipleLocator(5))

ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)

ax.grid()

# %% [markdown]
# # Aula 3

# %%
fig.suptitle("Imigração na América Latina",fontsize=14)

# Customização do gráfico
# Out:
# Text(0.5, 0.98, 'Imigração na América Latina')

# %%
# Criando um subplot
fig, axs = plt.subplots(2,2,figsize=(15,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Imigração na América Latina", fontsize=14)
# wspace - espaço horizontal
# hspace -espaço vertical

# subplots 
# Brasil
axs[0,0].plot(df.loc['Brasil',anos], color='green')
axs[0,0].set_title('Brasil')
axs[0,0].xaxis.set_major_locator(MultipleLocator(5))

# Colômbia
axs[0,1].plot(df.loc['Colômbia',anos], color='darkorange')
axs[0,1].set_title('Colômbia')
axs[0,1].xaxis.set_major_locator(MultipleLocator(5))

# Argentina
axs[1,0].plot(df.loc['Argentina',anos], color='dodgerblue')
axs[1,0].set_title('Argentina')
axs[1,0].xaxis.set_major_locator(MultipleLocator(5))

# Peru
axs[1,1].plot(df.loc['Peru',anos], color='red')
axs[1,1].set_title('Peru')
axs[1,1].xaxis.set_major_locator(MultipleLocator(5))

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
    ax.set_xlabel('Ano', fontsize=10)
    ax.set_ylabel('Número de Imigrantes', fontsize=10)


# Usando ravel() - achatar a matriz evitandoo uso completo 
# Usando set_ylim() - definindo o limite dos valores.
ymin = 0
ymax = 7000

for ax in axs.ravel():
    ax.set_ylim(ymin,ymax)

plt.show()

# %%
plt.figure(figsize=(14,5))
# plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='green',markersize=3, marker='o',markerfacecolor='white' )
plt.plot(dados_brasil['ano'],dados_brasil['imigrantes'], color='green')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500,1000,1500,2000,2500,3000])
plt.title('Gráfico de imigração de Brasileiros para o Canadá', color='green', loc='left')
plt.xlabel('Ano',fontsize=14)
plt.ylabel('imigrantes',fontsize=16)
plt.annotate('(Pico de imigração)', xy=(28, 2760), xytext=(40, 1700),
             arrowprops=dict(facecolor='red', shrink=0.20))
plt.fill_between(dados_brasil['ano'], dados_brasil['imigrantes'], color='darkgrey', alpha=0.7)

plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Mudando varias cores

# %%
america_sul = df.query('Região == "América do Sul"')
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %% [markdown]
# # Lista de cores

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# %%
for cor in cores:
    print(cor)
# Out:
# royalblue
# orange
# forestgreen
# orchid
# purple
# brown
# slateblue
# gray
# olive
# navy
# teal
# tomato

# %% [markdown]
# # Criando uma figura

# %%
# Criando a figura

# criando uma variavel fig para a figura
# ax é variavel que representa o gráfico (eixo, valores ...)
fig, ax = plt.subplots(figsize=(12, 5))
# É um gráfico de bar (Matplotlib)
ax.bar(america_sul.index, america_sul['Total'], color=cores)
# Titulo alinhado a esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
# eixo y com fonte 14
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.set_xlabel('')

ax.yaxis.set_tick_params(labelsize=8)
ax.xaxis.set_tick_params(labelsize=8)


plt.show()

# %% [markdown]
# # Aula 4

# %%
! pip install seaborn

# %%
import seaborn as sns

# %%
# Configurar o estilo do gráfico
sns.set(style='whitegrid')

# Criando uma variável fig para a figura
fig, ax = plt.subplots(figsize=(10, 6))  # Aumentando a altura para melhor visualização

# Gráfico de barras horizontais (Matplotlib) com mais opções de estilo
bars = ax.barh(america_sul.index, america_sul['Total'], color=cores, height=0.8)

# Adicionar rótulos de dados nas barras
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=12, color='black')

# Título alinhado à esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)

# Eixo x com fonte 14
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

# Mudar as fontes dos ticks
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Adicionar grid horizontal
ax.xaxis.grid(True, linestyle='--', alpha=0.7)

# Ajustar o layout para não cortar os rótulos
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Criando um DataFrame novo e ordenado

# %%
america_do_sul_sorted = america_sul.sort_values('Total', ascending=True)
america_sul.head()
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
#
#            1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Argentina   237   196   213   519  ...  1153   847   620   540   467   459
# Bolívia      38    44    79   165  ...   134   139   107   143   214   180
# Brasil      145   130   205   244  ...   969  1181  1746  2138  2509  2598
# Chile       681   533   633  1454  ...   384   427   530   350   375   340
# Colômbia    235   214   257   376  ...  6424  6535  5357  5452  4652  5218
#
# ...

# %%
# Configurar o estilo do gráfico
sns.set(style='whitegrid')

# Criando uma variável fig para a figura

fig, ax = plt.subplots(figsize=(10, 6))  # Aumentando a altura para melhor visualização

# Gráfico de barras horizontais (Matplotlib) com mais opções de estilo
bars = ax.barh(america_do_sul_sorted.index, america_do_sul_sorted['Total'], color=cores, height=0.8)

# Adicionar rótulos de dados nas barras
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=12, color='black')

# Título alinhado à esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)

# Eixo x com fonte 14
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

# Mudar as fontes dos ticks
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Adicionar grid horizontal
ax.xaxis.grid(True, linestyle='--', alpha=0.7)

# Ajustar o layout para não cortar os rótulos
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# ### Desafio
# ### O lider solicitou um gráfico
# ### O gráfico deve ter um destaque para o Brasil
# ### Todos os outros deverão ficar na cor cinza claro ou similar

# %%
# Configurar o estilo do gráfico
sns.set(style='whitegrid')

# Criando uma variável fig para a figura

fig, ax = plt.subplots(figsize=(10, 6))  # Aumentando a altura para melhor visualização

# Gráfico de barras horizontais (Matplotlib) com mais opções de estilo
bars = ax.barh(america_do_sul_sorted.index, america_do_sul_sorted['Total'], color='darkgrey', height=0.8)

# Destacar a barra do Brasil com a cor verde
for bar, label in zip(bars, america_do_sul_sorted.index):
    if label == 'Brasil': 
        bar.set_color('green')

"""       
para cada barra, label em (barras e america_do_sul_sorted.index) faça
    se label for igual a 'Brasil' então
        definir a cor da barra como 'verde'

"""
# Outra solução
"""
cores[]
for pais in america_sul_sorted.index:
    if pais == 'Brasil':
        cores.append('green')
    else:
        cores.append('silver')
"""
for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center', ha='left', fontsize=12, color='black')
"""
para cada barra em barras faça
    largura = obter_largura(barra)
    adicionar_texto_ao_eixo(
        largura + 0.02 * largura, 
        obter_y(barra) + obter_altura(barra) / 2,
        converter_para_texto_inteiro(largura), 
        alinhamento_vertical = 'centro', 
        alinhamento_horizontal = 'esquerda', 
        tamanho_da_fonte = 12, 
        cor = 'preto')
"""
# Título alinhado à esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)

# Eixo x com fonte 14
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

# Mudar as fontes dos ticks
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Adicionar grid horizontal
ax.xaxis.grid(True, linestyle='--', alpha=0.7)

# Ajustar o layout para não cortar os rótulos
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Mostrar os valores (anotações) em cada barra

# %%
# Configurar o estilo do gráfico
sns.set(style='whitegrid')

# Criando uma variável fig para a figura

fig, ax = plt.subplots(figsize=(12, 6))  # Aumentando a altura para melhor visualização

# Gráfico de barras horizontais (Matplotlib) com mais opções de estilo
bars = ax.barh(america_do_sul_sorted.index, america_do_sul_sorted['Total'], color='darkgrey', height=0.8)

# Destacar a barra do Brasil com a cor verde
for bar, label in zip(bars, america_do_sul_sorted.index):
    if label == 'Brasil': 
        bar.set_color('green')


for bar in bars:
    width = bar.get_width()
    ax.text(width + 0.02 / width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center',fontsize=12, color='black')

# Título alinhado à esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)

# Eixo x com fonte 14
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

# Mudar as fontes dos ticks
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.grid()
# Ajustar o layout para não cortar os rótulos
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Configurar o estilo do gráfico
sns.set(style='darkgrid')

# Criando uma variável fig para a figura

fig, ax = plt.subplots(figsize=(14, 6))  # Aumentando a altura para melhor visualização

# Gráfico de barras horizontais (Matplotlib) com mais opções de estilo
graf = ax.barh(america_do_sul_sorted.index, america_do_sul_sorted['Total'], color='darkgrey', height=0.8)

# Destacar a barra do Brasil com a cor verde
for bar, label in zip(graf, america_do_sul_sorted.index):
    if label == 'Brasil': 
        bar.set_color('green')


for bar in graf:
    width = bar.get_width()
    ax.text(width + 0.01 * width, bar.get_y() + bar.get_height() / 2,
            f'{width:.0f}', va='center',fontsize=10, color='black')

# Título alinhado à esquerda com fonte 18
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', fontsize=18)

# Eixo x com fonte 14
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

# Mudar as fontes dos ticks
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Ajustar o layout para não cortar os rótulos
#plt.tight_layout()

# Exibir o gráfico
plt.show()
